# %%
# Arnaud Guzman-Annès

# TSP - 9 locations

# %%
# Import libraries

import pulp as plp
from pulp import *
import numpy as np
from timeit import default_timer as timer
# Out:
# Using license file /Users/arnaudguzman-annes/gurobi.lic
# Academic license - for non-commercial use only
# No parameters matching '_test' found

# %%
# Costs

cost = np.array([[0, 45, 64, 25, 60, 32, 30, 70, 40],
                 [45, 0, 30, 42, 48, 25, 38, 50, 26],
                 [64, 30, 0, 20, 50, 37, 42, 50, 60],
                 [25, 42, 20, 0, 24, 56, 62, 27, 53],
                 [60, 48, 50, 24, 0, 28, 38, 46, 52],
                 [32, 25, 37, 56, 28, 0, 60, 49, 24],
                 [30, 38, 42, 62, 38, 60, 0, 64, 49],
                 [70, 50, 50, 27, 46, 49, 64, 0, 50],
                 [40, 26, 60, 53, 52, 24, 49, 50, 0]])

# %%
# Routes

I = range(0, cost.shape[0])
J = range(0, cost.shape[1])

x = plp.LpVariable.dicts(name='X', indexs=(I,J), cat=plp.LpBinary)

# %%
# Objective

prob = plp.LpProblem("Travel_Salesman_Problem")
prob.sense = plp.LpMinimize
prob += plp.lpSum(cost[i][j] * x[i][j] for i in I for j in J)

# %%
# Constraints - Part 1 - Enter and exit once

# (1) Salesman must enter each location exactly once:

for j in J:
    prob += plp.lpSum(x[i][j] for i in I) == 1
    
# (2) Salesman must exit each location exactly once:

for i in I:
    prob += plp.lpSum(x[i][j] for j in J) == 1

# %%
# Constraints - Part 2 - sub-tours

Y = range(0, cost.shape[0]-1)
y = plp.LpVariable.dicts(name='y', indexs=(Y), lowBound=0, upBound=cost.shape[0]-1, cat=plp.LpInteger)

# (1) Avoiding coming back to the same knot:

for i in I:
    prob += (x[i][i] == 0)

# (2) Avoiding sub-tours:

for i in Y:
    for j in Y:
        prob += y[i] - y[j] + cost.shape[0]*x[i][j] <= cost.shape[0]-1

# %%
prob
# Out:
# Travel_Salesman_Problem:
# MINIMIZE
# 45*X_0_1 + 64*X_0_2 + 25*X_0_3 + 60*X_0_4 + 32*X_0_5 + 30*X_0_6 + 70*X_0_7 + 40*X_0_8 + 45*X_1_0 + 30*X_1_2 + 42*X_1_3 + 48*X_1_4 + 25*X_1_5 + 38*X_1_6 + 50*X_1_7 + 26*X_1_8 + 64*X_2_0 + 30*X_2_1 + 20*X_2_3 + 50*X_2_4 + 37*X_2_5 + 42*X_2_6 + 50*X_2_7 + 60*X_2_8 + 25*X_3_0 + 42*X_3_1 + 20*X_3_2 + 24*X_3_4 + 56*X_3_5 + 62*X_3_6 + 27*X_3_7 + 53*X_3_8 + 60*X_4_0 + 48*X_4_1 + 50*X_4_2 + 24*X_4_3 + 28*X_4_5 + 38*X_4_6 + 46*X_4_7 + 52*X_4_8 + 32*X_5_0 + 25*X_5_1 + 37*X_5_2 + 56*X_5_3 + 28*X_5_4 + 60*X_5_6 + 49*X_5_7 + 24*X_5_8 + 30*X_6_0 + 38*X_6_1 + 42*X_6_2 + 62*X_6_3 + 38*X_6_4 + 60*X_6_5 + 64*X_6_7 + 49*X_6_8 + 70*X_7_0 + 50*X_7_1 + 50*X_7_2 + 27*X_7_3 + 46*X_7_4 + 49*X_7_5 + 64*X_7_6 + 50*X_7_8 + 40*X_8_0 + 26*X_8_1 + 60*X_8_2 + 53*X_8_3 + 52*X_8_4 + 24*X_8_5 + 49*X_8_6 + 50*X_8_7 + 0
# SUBJECT TO
# _C1: X_0_0 + X_1_0 + X_2_0 + X_3_0 + X_4_0 + X_5_0 + X_6_0 + X_7_0 + X_8_0 = 1
#
# _C2: X_0_1 + X_1_1 + X_2_1 + X_3_1 + X_4_1 + X_5_1 + X_6_1 + X_7_1 + X_8_1 = 1
#
# _C3: X_0_2 + X_1_2 + X_2_2 + X_3_2 + X_4_2 + X_5_2 + X_6_2 + X_7_2 + X_8_2 = 1
#
# _C4: X_0_3 + X_1_3 + X_2_3 + X_3_3 + X_4_3 + X_5_3 + X_6_3 + X_7_3 + X_8_3 = 1
#
# _C5: X_0_4 + X_1_4 + X_2_4 + X_3_4 + X_4_4 + X_5_4 + X_6_4 + X_7_4 + X_8_4 = 1
#
# _C6: X_0_5 + X_1_5 + X_2_5 + X_3_5 + X_4_5 + X_5_5 + X_6_5 + X_7_5 + X_8_5 = 1
#
# _C7: X_0_6 + X_1_6 + X_2_6 + X_3_6 + X_4_6 + X_5_6 + X_6_6 + X_7_6 + X_8_6 = 1
#
# _C8: X_0_7 + X_1_7 + X_2_7 + X_3_7 + X_4_7 + X_5_7 + X_6_7 + X_7_7 + X_8_7 = 1
#
# _C9: X_0_8 + X_1_8 + X_2_8 + X_3_8 + X_4_8 + X_5_8 + X_6_8 + X_7_8 + X_8_8 = 1
#
# _C10: X_0_0 + X_0_1 + X_0_2 + X_0_3 + X_0_4 + X_0_5 + X_0_6 + X_0_7 + X_0_8
#  = 1
#
# _C11: X_1_0 + X_1_1 + X_1_2 + X_1_3 + X_1_4 + X_1_5 + X_1_6 + X_1_7 + X_1_8
#  = 1
#
# _C12: X_2_0 + X_2_1 + X_2_2 + X_2_3 + X_2_4 + X_2_5 + X_2_6 + X_2_7 + X_2_8
#  = 1
#
# _C13: X_3_0 + X_3_1 + X_3_2 + X_3_3 + X_3_4 + X_3_5 + X_3_6 + X_3_7 + X_3_8
#  = 1
#
# _C14: X_4_0 + X_4_1 + X_4_2 + X_4_3 + X_4_4 + X_4_5 + X_4_6 + X_4_7 + X_4_8
#  = 1
#
# _C15: X_5_0 + X_5_1 + X_5_2 + X_5_3 + X_5_4 + X_5_5 + X_5_6 + X_5_7 + X_5_8
#  = 1
#
# _C16: X_6_0 + X_6_1 + X_6_2 + X_6_3 + X_6_4 + X_6_5 + X_6_6 + X_6_7 + X_6_8
#  = 1
#
# _C17: X_7_0 + X_7_1 + X_7_2 + X_7_3 + X_7_4 + X_7_5 + X_7_6 + X_7_7 + X_7_8
#  = 1
#
# _C18: X_8_0 + X_8_1 + X_8_2 + X_8_3 + X_8_4 + X_8_5 + X_8_6 + X_8_7 + X_8_8
#  = 1
#
# _C19: X_0_0 = 0
#
# _C20: X_1_1 = 0
#
# _C21: X_2_2 = 0
#
# _C22: X_3_3 = 0
#
# _C23: X_4_4 = 0
#
# _C24: X_5_5 = 0
#
# _C25: X_6_6 = 0
#
# _C26: X_7_7 = 0
#
# _C27: X_8_8 = 0
#
# _C28: 9 X_0_0 + 0 y_0 <= 8
#
# _C29: 9 X_0_1 + y_0 - y_1 <= 8
#
# _C30: 9 X_0_2 + y_0 - y_2 <= 8
#
# _C31: 9 X_0_3 + y_0 - y_3 <= 8
#
# _C32: 9 X_0_4 + y_0 - y_4 <= 8
#
# _C33: 9 X_0_5 + y_0 - y_5 <= 8
#
# _C34: 9 X_0_6 + y_0 - y_6 <= 8
#
# _C35: 9 X_0_7 + y_0 - y_7 <= 8
#
# _C36: 9 X_1_0 - y_0 + y_1 <= 8
#
# _C37: 9 X_1_1 + 0 y_1 <= 8
#
# _C38: 9 X_1_2 + y_1 - y_2 <= 8
#
# _C39: 9 X_1_3 + y_1 - y_3 <= 8
#
# _C40: 9 X_1_4 + y_1 - y_4 <= 8
#
# _C41: 9 X_1_5 + y_1 - y_5 <= 8
#
# _C42: 9 X_1_6 + y_1 - y_6 <= 8
#
# _C43: 9 X_1_7 + y_1 - y_7 <= 8
#
# _C44: 9 X_2_0 - y_0 + y_2 <= 8
#
# _C45: 9 X_2_1 - y_1 + y_2 <= 8
#
# _C46: 9 X_2_2 + 0 y_2 <= 8
#
# _C47: 9 X_2_3 + y_2 - y_3 <= 8
#
# _C48: 9 X_2_4 + y_2 - y_4 <= 8
#
# _C49: 9 X_2_5 + y_2 - y_5 <= 8
#
# _C50: 9 X_2_6 + y_2 - y_6 <= 8
#
# _C51: 9 X_2_7 + y_2 - y_7 <= 8
#
# _C52: 9 X_3_0 - y_0 + y_3 <= 8
#
# _C53: 9 X_3_1 - y_1 + y_3 <= 8
#
# _C54: 9 X_3_2 - y_2 + y_3 <= 8
#
# _C55: 9 X_3_3 + 0 y_3 <= 8
#
# _C56: 9 X_3_4 + y_3 - y_4 <= 8
#
# _C57: 9 X_3_5 + y_3 - y_5 <= 8
#
# _C58: 9 X_3_6 + y_3 - y_6 <= 8
#
# _C59: 9 X_3_7 + y_3 - y_7 <= 8
#
# _C60: 9 X_4_0 - y_0 + y_4 <= 8
#
# _C61: 9 X_4_1 - y_1 + y_4 <= 8
#
# _C62: 9 X_4_2 - y_2 + y_4 <= 8
#
# _C63: 9 X_4_3 - y_3 + y_4 <= 8
#
# _C64: 9 X_4_4 + 0 y_4 <= 8
#
# _C65: 9 X_4_5 + y_4 - y_5 <= 8
#
# _C66: 9 X_4_6 + y_4 - y_6 <= 8
#
# _C67: 9 X_4_7 + y_4 - y_7 <= 8
#
# _C68: 9 X_5_0 - y_0 + y_5 <= 8
#
# _C69: 9 X_5_1 - y_1 + y_5 <= 8
#
# _C70: 9 X_5_2 - y_2 + y_5 <= 8
#
# _C71: 9 X_5_3 - y_3 + y_5 <= 8
#
# _C72: 9 X_5_4 - y_4 + y_5 <= 8
#
# _C73: 9 X_5_5 + 0 y_5 <= 8
#
# _C74: 9 X_5_6 + y_5 - y_6 <= 8
#
# _C75: 9 X_5_7 + y_5 - y_7 <= 8
#
# _C76: 9 X_6_0 - y_0 + y_6 <= 8
#
# _C77: 9 X_6_1 - y_1 + y_6 <= 8
#
# _C78: 9 X_6_2 - y_2 + y_6 <= 8
#
# _C79: 9 X_6_3 - y_3 + y_6 <= 8
#
# _C80: 9 X_6_4 - y_4 + y_6 <= 8
#
# _C81: 9 X_6_5 - y_5 + y_6 <= 8
#
# _C82: 9 X_6_6 + 0 y_6 <= 8
#
# _C83: 9 X_6_7 + y_6 - y_7 <= 8
#
# _C84: 9 X_7_0 - y_0 + y_7 <= 8
#
# _C85: 9 X_7_1 - y_1 + y_7 <= 8
#
# _C86: 9 X_7_2 - y_2 + y_7 <= 8
#
# _C87: 9 X_7_3 - y_3 + y_7 <= 8
#
# _C88: 9 X_7_4 - y_4 + y_7 <= 8
#
# _C89: 9 X_7_5 - y_5 + y_7 <= 8
#
# _C90: 9 X_7_6 - y_6 + y_7 <= 8
#
# _C91: 9 X_7_7 + 0 y_7 <= 8
#
# VARIABLES
# 0 <= X_0_0 <= 1 Integer
# 0 <= X_0_1 <= 1 Integer
# 0 <= X_0_2 <= 1 Integer
# 0 <= X_0_3 <= 1 Integer
# 0 <= X_0_4 <= 1 Integer
# 0 <= X_0_5 <= 1 Integer
# 0 <= X_0_6 <= 1 Integer
# 0 <= X_0_7 <= 1 Integer
# 0 <= X_0_8 <= 1 Integer
# 0 <= X_1_0 <= 1 Integer
# 0 <= X_1_1 <= 1 Integer
# 0 <= X_1_2 <= 1 Integer
# 0 <= X_1_3 <= 1 Integer
# 0 <= X_1_4 <= 1 Integer
# 0 <= X_1_5 <= 1 Integer
# 0 <= X_1_6 <= 1 Integer
# 0 <= X_1_7 <= 1 Integer
# 0 <= X_1_8 <= 1 Integer
# 0 <= X_2_0 <= 1 Integer
# 0 <= X_2_1 <= 1 Integer
# 0 <= X_2_2 <= 1 Integer
# 0 <= X_2_3 <= 1 Integer
# 0 <= X_2_4 <= 1 Integer
# 0 <= X_2_5 <= 1 Integer
# 0 <= X_2_6 <= 1 Integer
# 0 <= X_2_7 <= 1 Integer
# 0 <= X_2_8 <= 1 Integer
# 0 <= X_3_0 <= 1 Integer
# 0 <= X_3_1 <= 1 Integer
# 0 <= X_3_2 <= 1 Integer
# 0 <= X_3_3 <= 1 Integer
# 0 <= X_3_4 <= 1 Integer
# 0 <= X_3_5 <= 1 Integer
# 0 <= X_3_6 <= 1 Integer
# 0 <= X_3_7 <= 1 Integer
# 0 <= X_3_8 <= 1 Integer
# 0 <= X_4_0 <= 1 Integer
# 0 <= X_4_1 <= 1 Integer
# 0 <= X_4_2 <= 1 Integer
# 0 <= X_4_3 <= 1 Integer
# 0 <= X_4_4 <= 1 Integer
# 0 <= X_4_5 <= 1 Integer
# 0 <= X_4_6 <= 1 Integer
# 0 <= X_4_7 <= 1 Integer
# 0 <= X_4_8 <= 1 Integer
# 0 <= X_5_0 <= 1 Integer
# 0 <= X_5_1 <= 1 Integer
# 0 <= X_5_2 <= 1 Integer
# 0 <= X_5_3 <= 1 Integer
# 0 <= X_5_4 <= 1 Integer
# 0 <= X_5_5 <= 1 Integer
# 0 <= X_5_6 <= 1 Integer
# 0 <= X_5_7 <= 1 Integer
# 0 <= X_5_8 <= 1 Integer
# 0 <= X_6_0 <= 1 Integer
# 0 <= X_6_1 <= 1 Integer
# 0 <= X_6_2 <= 1 Integer
# 0 <= X_6_3 <= 1 Integer
# 0 <= X_6_4 <= 1 Integer
# 0 <= X_6_5 <= 1 Integer
# 0 <= X_6_6 <= 1 Integer
# 0 <= X_6_7 <= 1 Integer
# 0 <= X_6_8 <= 1 Integer
# 0 <= X_7_0 <= 1 Integer
# 0 <= X_7_1 <= 1 Integer
# 0 <= X_7_2 <= 1 Integer
# 0 <= X_7_3 <= 1 Integer
# 0 <= X_7_4 <= 1 Integer
# 0 <= X_7_5 <= 1 Integer
# 0 <= X_7_6 <= 1 Integer
# 0 <= X_7_7 <= 1 Integer
# 0 <= X_7_8 <= 1 Integer
# 0 <= X_8_0 <= 1 Integer
# 0 <= X_8_1 <= 1 Integer
# 0 <= X_8_2 <= 1 Integer
# 0 <= X_8_3 <= 1 Integer
# 0 <= X_8_4 <= 1 Integer
# 0 <= X_8_5 <= 1 Integer
# 0 <= X_8_6 <= 1 Integer
# 0 <= X_8_7 <= 1 Integer
# 0 <= X_8_8 <= 1 Integer
# 0 <= y_0 <= 8 Integer
# 0 <= y_1 <= 8 Integer
# 0 <= y_2 <= 8 Integer
# 0 <= y_3 <= 8 Integer
# 0 <= y_4 <= 8 Integer
# 0 <= y_5 <= 8 Integer
# 0 <= y_6 <= 8 Integer
# 0 <= y_7 <= 8 Integer

# %%
# Solve and Time

start_time = timer()
prob.solve()
end_time = timer()

# %%
# The status of the solution is printed to the screen
print("="*30,"\nSolution Status:", plp.LpStatus[prob.status])

# Results
obj = value(prob.objective)
print("Optimal Result: ${}".format(obj))

print("TSP path:")
for v in prob.variables():
    if v.varValue != 0:
        if v.varValue == 1 and v.name != "y_0":
            print(v.name)

# Time
print("Time required:", round(end_time-start_time,4), "s")
# Out:
# ==============================
# Solution Status: Optimal
# Optimal Result: $273.0
# TSP path:
# X_0_6
# X_1_8
# X_2_1
# X_3_2
# X_4_7
# X_5_0
# X_6_4
# X_7_3
# X_8_5
# Time required: 0.4582 s
